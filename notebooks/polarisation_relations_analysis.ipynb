# %%
# Apparently ipython notebook doesn't use PYTHONPATH... what?
import os, sys
lib_path = os.path.abspath('../python')
if lib_path not in sys.path:
    sys.path.append(lib_path)

import emapex
import matplotlib.pyplot as plt

E76 = emapex.EMApexFloat('../../data/EM-APEX/allprofs11.mat', 4976)
E76.apply_w_model('../../data/EM-APEX/4976_fix_p0k0M_fit_info.p')
E76.apply_strain('../../data/EM-APEX/4976_N2_ref_300dbar.p')
E76.apply_isopycnal_displacement('../../data/EM-APEX/srho_4976_100mbin.p')

E77 = emapex.EMApexFloat('../../data/EM-APEX/allprofs11.mat', 4977)
E77.apply_w_model('../../data/EM-APEX/4977_fix_p0k0M_fit_info.p')
E77.apply_strain('../../data/EM-APEX/4977_N2_ref_300dbar.p')
E77.apply_isopycnal_displacement('../../data/EM-APEX/srho_4977_100mbin.p')

# %matplotlib inline
# %qtconsole
# Out:
# Initialising
# ------------
#
# EM-APEX float: 4976
# Loading data...
#   Loaded: Verr1.
#   Loaded: Verr2.
#   Loaded: lat_up.
#   Loaded: V.
#   Loaded: U1.
#   Loaded: Wp_ca.
#   Loaded: U2.
#   Loaded: lon_down.
# * Skipping: Nskip.
#   Loaded: ind.
#   Loaded: Pef.
#   Loaded: u_sfc.
#   Loaded: V2woW.
#   Loaded: magvar.
#   Loaded: gps_dist.
#   Loaded: got_gps.
#   Loaded: Wr.
#   Loaded: ssid.
#   Loaded: lat_gps.
#   Loaded: maxp.
#   Loaded: apf9_terr.
#   Loaded: botdep.
#   Loaded: utc_dep.
#   Loaded: vbsid.
#   Loaded: V2.
#   Loaded: utc_down.
#   Loaded: v_gps.
#   Loaded: surfaced.
#   Loaded: argo_mode.
# * Skipping: __version__.
#   Loaded: V1woW.
#   Loaded: P_ca.
#   Loaded: UTC.
#   Loaded: Wf.
#   Loaded: ppos.
#   Loaded: ubs.
#   Loaded: utc_gps.
#   Loaded: UTCef.
#   Loaded: Wp.
#   Loaded: mlt_ca.
#   Loaded: lat_down.
#   Loaded: P.
#   Loaded: S.
#   Loaded: U.
#   Loaded: T.
#   Loaded: u_gps.
#   Loaded: v_sfc.
#   Loaded: nvel.
#   Loaded: ppos_ca.
#   Loaded: depl.
#   Loaded: Vchan.
#   Loaded: utc_up.
# * Skipping: __header__.
#   Loaded: utc_rec.
# * Skipping: __globals__.
#   Loaded: vbs.
#   Loaded: V1.
#   Loaded: lon_gps.
#   Loaded: lon_up.
# All numerical data appears to have been loaded successfully.
#
# Interpolated GPS positions to starts and ends of profiles.
# Calculating heights.
# Creating array of half profiles.
# Post processing
# ---------------
#
# Calculating distance along trajectory.
# Interpolating distance to measurements.
# Estimating bearings.
# Calculating sub-surface velocity.
# Interpolating missing velocity values.
# Estimating absolute velocity.
# Calculating thermodynamic variables.
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:783: RuntimeWarning: invalid value encountered in greater_equal
#   return umath.absolute(a) * self.tolerance >= umath.absolute(b)
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:795: RuntimeWarning: invalid value encountered in less_equal
#   return umath.less_equal(x, self.critical_value)
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:60: RuntimeWarning: invalid value encountered in less
#   cond1 = ((p < 100) & (SP > 120))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:60: RuntimeWarning: invalid value encountered in greater
#   cond1 = ((p < 100) & (SP > 120))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:61: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = ((p >= 100) & (SP > 42))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:61: RuntimeWarning: invalid value encountered in greater
#   cond2 = ((p >= 100) & (SP > 42))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:428: RuntimeWarning: invalid value encountered in less
#   invalid = np.logical_and(p < 100, np.logical_or(t > 80, t < -12))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:428: RuntimeWarning: invalid value encountered in greater
#   invalid = np.logical_and(p < 100, np.logical_or(t > 80, t < -12))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:431: RuntimeWarning: invalid value encountered in greater_equal
#   invalid = np.logical_and(p >= 100, np.logical_or(t > 40, t < -12))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:431: RuntimeWarning: invalid value encountered in greater
#   invalid = np.logical_and(p >= 100, np.logical_or(t > 40, t < -12))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/conversions.py:431: RuntimeWarning: invalid value encountered in less
#   invalid = np.logical_and(p >= 100, np.logical_or(t > 40, t < -12))
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/utilities/utilities.py:251: RuntimeWarning: invalid value encountered in less
#   SA[SA < 0] = np.ma.masked
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:807: RuntimeWarning: invalid value encountered in less
#   return umath.less(x, self.critical_value)
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/library.py:899: RuntimeWarning: invalid value encountered in greater
#   nonzero_SA = np.any(SA > 0)
# Calculating float vertical velocity.
# Renaming Wp to Wpef.
# Calculating shear.
# Regridding piston position to ctd.
# Updating half profiles.
#
#
# Applying vertical velocity model
# --------------------------------
#
# Unpickling fit info.
#   Added: Ws.
#   Added: Ww.
#
# Updating half profiles.
#
#
# Adding strain
# -------------
#
#   Added: N2_ref.
#   Added: strain_z.
#
# Updating half profiles.
#
#
# Adding isopycnal displacements.
# -------------------------------
#
#   Added: srho_1.
#   Added: mu.
#   Added: b.
# Updating half profiles.
#
#
# Initialising
# ------------
#
# EM-APEX float: 4977
# Loading data...
#   Loaded: Verr1.
#   Loaded: Verr2.
#   Loaded: lat_up.
#   Loaded: V.
#   Loaded: U1.
#   Loaded: Wp_ca.
#   Loaded: U2.
#   Loaded: lon_down.
# * Skipping: Nskip.
#   Loaded: ind.
#   Loaded: Pef.
#   Loaded: u_sfc.
#   Loaded: V2woW.
#   Loaded: magvar.
#   Loaded: gps_dist.
#   Loaded: got_gps.
#   Loaded: Wr.
#   Loaded: ssid.
#   Loaded: lat_gps.
#   Loaded: maxp.
#   Loaded: apf9_terr.
#   Loaded: botdep.
#   Loaded: utc_dep.
#   Loaded: vbsid.
#   Loaded: V2.
#   Loaded: utc_down.
#   Loaded: v_gps.
#   Loaded: surfaced.
#   Loaded: argo_mode.
# * Skipping: __version__.
#   Loaded: V1woW.
#   Loaded: P_ca.
#   Loaded: UTC.
#   Loaded: Wf.
#   Loaded: ppos.
#   Loaded: ubs.
#   Loaded: utc_gps.
#   Loaded: UTCef.
#   Loaded: Wp.
#   Loaded: mlt_ca.
#   Loaded: lat_down.
#   Loaded: P.
#   Loaded: S.
#   Loaded: U.
#   Loaded: T.
#   Loaded: u_gps.
#   Loaded: v_sfc.
#   Loaded: nvel.
#   Loaded: ppos_ca.
#   Loaded: depl.
#   Loaded: Vchan.
#   Loaded: utc_up.
# * Skipping: __header__.
#   Loaded: utc_rec.
# * Skipping: __globals__.
#   Loaded: vbs.
#   Loaded: V1.
#   Loaded: lon_gps.
#   Loaded: lon_up.
# All numerical data appears to have been loaded successfully.
#
# Interpolated GPS positions to starts and ends of profiles.
# Calculating heights.
# Creating array of half profiles.
# Post processing
# ---------------
#
# Calculating distance along trajectory.
# Interpolating distance to measurements.
# Estimating bearings.
# /noc/users/jc3e13/emapex/python/vertical_velocity_model.py:187: RuntimeWarning: invalid value encountered in less
#   is_going_down = float_volume < effective_water_volume
# /noc/users/jc3e13/anaconda/lib/python2.7/site-packages/gsw/gibbs/water_column_48.py:232: RuntimeWarning: divide by zero encountered in true_divide
#   N2 = (grav_mid ** 2 / db2Pascal) * (rho_mid / dp)
# Calculating sub-surface velocity.
# Interpolating missing velocity values.
# Estimating absolute velocity.
# Calculating thermodynamic variables.
# Calculating float vertical velocity.
# Renaming Wp to Wpef.
# Calculating shear.
# Regridding piston position to ctd.
# Updating half profiles.
#
#
# Applying vertical velocity model
# --------------------------------
#
# Unpickling fit info.
#   Added: Ws.
#   Added: Ww.
#
# Updating half profiles.
#
#
# Adding strain
# -------------
#
#   Added: N2_ref.
#   Added: strain_z.
#
# Updating half profiles.
#
#
# Adding isopycnal displacements.
# -------------------------------
#
#   Added: srho_1.
#   Added: mu.
#   Added: b.
# Updating half profiles.
# /noc/users/jc3e13/emapex/python/utils.py:202: RuntimeWarning: invalid value encountered in divide
#   dydx = np.diff(y_nn)/np.diff(x_nn)

# %%
E76_hpids = np.arange(31, 33)
E77_hpids = np.arange(25, 28)

for Float, hpids in zip([E76, E77], [E76_hpids, E77_hpids]):
    __, idxs = Float.get_profiles(hpids, ret_idxs=True)
    
    z = Float.z[:, idxs]
    zef = Float.zef[:, idxs]
    u = Float.U_abs[:, idxs]
    v = Float.V_abs[:, idxs]
    w = Float.Ww[:, idxs]
    b = Float.b[:, idxs]
    N = np.sqrt(Float.N2_ref[:, idxs])
    
    fig, axs = plt.subplots(1, 5, sharey=True, figsize=(16,6))
    axs[0].set_ylabel('$z$ (m)')
    axs[0].plot(u, zef)
    axs[0].set_xlabel('$u$')
    axs[1].plot(v, zef)
    axs[1].set_xlabel('$v$')
    axs[2].plot(w, z)
    axs[2].set_xlabel('$w$')
    axs[3].plot(b, z)
    axs[3].set_xlabel('$b$')
    axs[4].plot(N, z)
    axs[4].set_xlabel('$N$')
    
    for ax in axs:
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)

# %%
w_amp = np.array([-0.2])
b_amp = np.array([4e-4])
u_amp
N = 0.002
f = 1.2e-4

om = np.abs(w_amp*N**2/b_amp)

r = np.abs((1j*u_amp/v_amp*f + om)/(u_amp/v_amp*om - 1j*f))

print(om)
print
# Out:
# [ 0.002]
